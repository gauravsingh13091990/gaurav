# %%
adult = read.csv('Adult.csv')

# %%
#Q1 how many row's of data in dataset
#Q2 how many variables in the dataset
str(adult)
# Out:
# 'data.frame':	32561 obs. of  15 variables:
#  $ age           : int  39 50 38 53 28 37 49 52 31 42 ...
#  $ workclass     : Factor w/ 9 levels " ?"," Federal-gov",..: 8 7 5 5 5 5 5 7 5 5 ...
#  $ fnlwgt        : int  77516 83311 215646 234721 338409 284582 160187 209642 45781 159449 ...
#  $ education     : Factor w/ 16 levels " 10th"," 11th",..: 10 10 12 2 10 13 7 12 13 10 ...
#  $ education.num : int  13 13 9 7 13 14 5 9 14 13 ...
#  $ marital.status: Factor w/ 7 levels " Divorced"," Married-AF-spouse",..: 5 3 1 3 3 3 4 3 5 3 ...
#  $ occupation    : Factor w/ 15 levels " ?"," Adm-clerical",..: 2 5 7 7 11 5 9 5 11 5 ...
#  $ relationship  : Factor w/ 6 levels " Husband"," Not-in-family",..: 2 1 2 1 6 6 2 1 2 1 ...
#  $ race          : Factor w/ 5 levels " Amer-Indian-Eskimo",..: 5 5 5 3 3 5 3 5 5 5 ...
#  $ sex           : Factor w/ 2 levels " Female"," Male": 2 2 2 2 1 1 1 2 1 2 ...
#  $ capital.gain  : int  2174 0 0 0 0 0 0 0 14084 5178 ...
# ...

# %%
#Q3 using the max function what is the maximum value of the variable capital gain?
max(adult$capital.gain)
# Out:
# [1] 99999

# %%
#Q4 what is the minimum value of the variable capital loss?
min(adult$capital.loss)
# Out:
# [1] 0

# %%
#Q5 how many observation have value female in sex variable?
summary(adult$sex)
# Out:
#  Female    Male
#   10771   21790

# %% [markdown]
# summary(adult$relationship)

# %%
#Q6 How many observation have relationship value of not in family?
summary(adult$relationship)
# Out:
#         Husband   Not-in-family  Other-relative       Own-child       Unmarried
#           13193            8305             981            5068            3446
#            Wife
#            1568

# %%
air =read.csv('AirQualityUCI.csv')

# %%
#Q7 In what format are the entries in the variable Date?
air$Date[1]
# Out:
# [1] 10-03-2004
# 391 Levels: 01-01-2005 01-02-2005 01-03-2005 01-04-2004 ... 31-12-2004

# %%
DateCon = as.Date(air$Date)
air$Date=DateCon
summary(DateCon)
# Out:
# ERROR while rich displaying an object: Error in nms[[i]]: subscript out of bounds
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_html.Date(obj)
# 9. repr_html_wrapper(obj, "<time datetime=\"%s\">%s</time>", ...)
# 10. repr_vector_generic(obj, "\t<li>%s</li>\n", "\t<dt>%s</dt>\n\t\t<dd>%s</dd>\n",
#   .     "<strong>%s:</strong> %s", "<ol class=list-inline>\n%s</ol>\n",
# ...

# %%
summary(DateCon)
# Out:
# ERROR while rich displaying an object: Error in nms[[i]]: subscript out of bounds
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_html.Date(obj)
# 9. repr_html_wrapper(obj, "<time datetime=\"%s\">%s</time>", ...)
# 10. repr_vector_generic(obj, "\t<li>%s</li>\n", "\t<dt>%s</dt>\n\t\t<dd>%s</dd>\n",
#   .     "<strong>%s:</strong> %s", "<ol class=list-inline>\n%s</ol>\n",
# ...

# %%
str(air$Date)
# Out:
#  Date[1:9357], format: NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA NA ...

# %%
summary(air)
# Out:
#          Date            Time          CO.GT.         PT08.S1.CO.
#  01-01-2005:  24   00:00:00: 390   Min.   :-200.00   Min.   :-200
#  01-02-2005:  24   01:00:00: 390   1st Qu.:   0.60   1st Qu.: 921
#  01-03-2005:  24   02:00:00: 390   Median :   1.50   Median :1053
#  01-04-2004:  24   03:00:00: 390   Mean   : -34.21   Mean   :1049
#  01-04-2005:  24   04:00:00: 390   3rd Qu.:   2.60   3rd Qu.:1221
#  01-05-2004:  24   05:00:00: 390   Max.   :  11.90   Max.   :2040
#  (Other)   :9213   (Other) :7017
#     NMHC.GT.         C6H6.GT.        PT08.S2.NMHC.       NOx.GT.
#  Min.   :-200.0   Min.   :-200.000   Min.   :-200.0   Min.   :-200.0
#  1st Qu.:-200.0   1st Qu.:   4.000   1st Qu.: 711.0   1st Qu.:  50.0
#  Median :-200.0   Median :   7.900   Median : 895.0   Median : 141.0
#  Mean   :-159.1   Mean   :   1.866   Mean   : 894.6   Mean   : 168.6
#  3rd Qu.:-200.0   3rd Qu.:  13.600   3rd Qu.:1105.0   3rd Qu.: 284.0
# ...

# %%
str(air)
# Out:
# 'data.frame':	9357 obs. of  15 variables:
#  $ Date         : Factor w/ 391 levels "01-01-2005","01-02-2005",..: 115 115 115 115 115 115 128 128 128 128 ...
#  $ Time         : Factor w/ 24 levels "00:00:00","01:00:00",..: 19 20 21 22 23 24 1 2 3 4 ...
#  $ CO.GT.       : num  2.6 2 2.2 2.2 1.6 1.2 1.2 1 0.9 0.6 ...
#  $ PT08.S1.CO.  : int  1360 1292 1402 1376 1272 1197 1185 1136 1094 1010 ...
#  $ NMHC.GT.     : int  150 112 88 80 51 38 31 31 24 19 ...
#  $ C6H6.GT.     : num  11.9 9.4 9 9.2 6.5 4.7 3.6 3.3 2.3 1.7 ...
#  $ PT08.S2.NMHC.: int  1046 955 939 948 836 750 690 672 609 561 ...
#  $ NOx.GT.      : int  166 103 131 172 131 89 62 62 45 -200 ...
#  $ PT08.S3.NOx. : int  1056 1174 1140 1092 1205 1337 1462 1453 1579 1705 ...
#  $ NO2.GT.      : int  113 92 114 122 116 96 77 76 60 -200 ...
#  $ PT08.S4.NO2. : int  1692 1559 1555 1584 1490 1393 1333 1333 1276 1235 ...
#  $ PT08.S5.O3.  : int  1268 972 1074 1203 1110 949 733 730 620 501 ...
# ...

# %%
year(as.Date(air$Date,'%d-%m-%y'))
# Out:
# Error in year(as.Date(air$Date, "%d-%m-%y")): could not find function "year"
# Traceback:

# %%
air2= read.csv('aircsv.csv')

# %%
air2
# Out:
#      Date       Time     CO.GT. PT08.S1.CO. NMHC.GT. C6H6.GT. PT08.S2.NMHC.
# 1    2004-10-03 18:00:00    2.6 1360        150      11.9     1046
# 2    2004-10-03 19:00:00    2.0 1292        112       9.4      955
# 3    2004-10-03 20:00:00    2.2 1402         88       9.0      939
# 4    2004-10-03 21:00:00    2.2 1376         80       9.2      948
# 5    2004-10-03 22:00:00    1.6 1272         51       6.5      836
# 6    2004-10-03 23:00:00    1.2 1197         38       4.7      750
# 7    2004-11-03 00:00:00    1.2 1185         31       3.6      690
# 8    2004-11-03 01:00:00    1.0 1136         31       3.3      672
# 9    2004-11-03 02:00:00    0.9 1094         24       2.3      609
# 10   2004-11-03 03:00:00    0.6 1010         19       1.7      561
# 11   2004-11-03 04:00:00 -200.0 1011         14       1.3      527
# 12   2004-11-03 05:00:00    0.7 1066          8       1.1      512
# 13   2004-11-03 06:00:00    0.7 1052         16       1.6      553
# ...

# %%
train=subset(air2,year<2005)

# %%
test = subset(air2,year>=2005)

# %%
model = lm(Temperature ~ CO.GT.+PT08.S1.CO.+NMHC.GT.+C6H6.GT.+PT08.S2.NMHC.+NOx.GT.+PT08.S3.NOx.+NO2.GT.+PT08.S4.NO2.+PT08.S5.O3.+AH+RH,data=train)

# %%
# Q16 Compute the model R square?
#Q17  which variable is significant in the model?We will consider a variable significant if p value is below 0.05
summary(model)
# Out:
# Call:
# lm(formula = Temperature ~ CO.GT. + PT08.S1.CO. + NMHC.GT. +
#     C6H6.GT. + PT08.S2.NMHC. + NOx.GT. + PT08.S3.NOx. + NO2.GT. +
#     PT08.S4.NO2. + PT08.S5.O3. + AH + RH, data = train)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -9.9780 -2.1366  0.0899  1.9441 18.4983
#
# Coefficients:
#                 Estimate Std. Error  t value Pr(>|t|)
# (Intercept)   24.9580106  1.0356896   24.098  < 2e-16 ***
# CO.GT.         0.0004982  0.0006279    0.793    0.428
# PT08.S1.CO.    0.0002727  0.0005233    0.521    0.602
# NMHC.GT.      -0.0084920  0.0002838  -29.920  < 2e-16 ***
# C6H6.GT.      -0.4312055  0.0331903  -12.992  < 2e-16 ***
# PT08.S2.NMHC. -0.0063171  0.0011574   -5.458 4.97e-08 ***
# NOx.GT.        0.0049218  0.0003889   12.657  < 2e-16 ***
# PT08.S3.NOx.  -0.0093174  0.0003281  -28.395  < 2e-16 ***
# NO2.GT.       -0.0070083  0.0006858  -10.219  < 2e-16 ***
# PT08.S4.NO2.   0.0200880  0.0002478   81.050  < 2e-16 ***
# ...

# %%
str(air2)
# Out:
# 'data.frame':	9357 obs. of  18 variables:
#  $ Date         : Factor w/ 391 levels "2004-01-04","2004-01-05",..: 212 212 212 212 212 212 241 241 241 241 ...
#  $ Time         : Factor w/ 24 levels "00:00:00","01:00:00",..: 19 20 21 22 23 24 1 2 3 4 ...
#  $ CO.GT.       : num  2.6 2 2.2 2.2 1.6 1.2 1.2 1 0.9 0.6 ...
#  $ PT08.S1.CO.  : int  1360 1292 1402 1376 1272 1197 1185 1136 1094 1010 ...
#  $ NMHC.GT.     : int  150 112 88 80 51 38 31 31 24 19 ...
#  $ C6H6.GT.     : num  11.9 9.4 9 9.2 6.5 4.7 3.6 3.3 2.3 1.7 ...
#  $ PT08.S2.NMHC.: int  1046 955 939 948 836 750 690 672 609 561 ...
#  $ NOx.GT.      : int  166 103 131 172 131 89 62 62 45 -200 ...
#  $ PT08.S3.NOx. : int  1056 1174 1140 1092 1205 1337 1462 1453 1579 1705 ...
#  $ NO2.GT.      : int  113 92 114 122 116 96 77 76 60 -200 ...
#  $ PT08.S4.NO2. : int  1692 1559 1555 1584 1490 1393 1333 1333 1276 1235 ...
#  $ PT08.S5.O3.  : int  1268 972 1074 1203 1110 949 733 730 620 501 ...
# ...

# %%
cor(train)
# Out:
# Error in cor(train): 'x' must be numeric
# Traceback:
#
# 1. cor(train)
# 2. stop("'x' must be numeric")

# %%
train
# Out:
#      Date       Time     CO.GT. PT08.S1.CO. NMHC.GT. C6H6.GT. PT08.S2.NMHC.
# 1    2004-10-03 18:00:00    2.6 1360        150      11.9     1046
# 2    2004-10-03 19:00:00    2.0 1292        112       9.4      955
# 3    2004-10-03 20:00:00    2.2 1402         88       9.0      939
# 4    2004-10-03 21:00:00    2.2 1376         80       9.2      948
# 5    2004-10-03 22:00:00    1.6 1272         51       6.5      836
# 6    2004-10-03 23:00:00    1.2 1197         38       4.7      750
# 7    2004-11-03 00:00:00    1.2 1185         31       3.6      690
# 8    2004-11-03 01:00:00    1.0 1136         31       3.3      672
# 9    2004-11-03 02:00:00    0.9 1094         24       2.3      609
# 10   2004-11-03 03:00:00    0.6 1010         19       1.7      561
# 11   2004-11-03 04:00:00 -200.0 1011         14       1.3      527
# 12   2004-11-03 05:00:00    0.7 1066          8       1.1      512
# 13   2004-11-03 06:00:00    0.7 1052         16       1.6      553
# ...

# %%
# drops <- c("x","z")
# DF[ , !(names(DF) %in% drops)]
drops <- c('Date','Time','month','weekday')
train=train[,!names(train) %in% drops]

# %%
# Compute the coorelation with all the variable in trainset .Which of the following variable highly corelated with
# independent variable CO corelation greater than 0.7?
# Which of the following variable AH is highly corelated with?
cor(train)
# Out:
# Warning message in cor(train):
# "the standard deviation is zero"
#               CO.GT.       PT08.S1.CO. NMHC.GT.     C6H6.GT.    PT08.S2.NMHC.
# CO.GT.         1.000000000 0.04623930   0.172739048 -0.01585276  0.0523336
# PT08.S1.CO.    0.046239298 1.00000000   0.200575847  0.83284311  0.9348014
# NMHC.GT.       0.172739048 0.20057585   1.000000000  0.02936226  0.1021265
# C6H6.GT.      -0.015852755 0.83284311   0.029362263  1.00000000  0.7561280
# PT08.S2.NMHC.  0.052333599 0.93480138   0.102126476  0.75612797  1.0000000
# NOx.GT.        0.551851184 0.27930136   0.051527484  0.01923986  0.3548322
# PT08.S3.NOx.  -0.036327333 0.01437696   0.028298779  0.45673801 -0.1598521
# NO2.GT.        0.699393326 0.17394619   0.176784761  0.02435532  0.2264870
# PT08.S4.NO2.  -0.006451312 0.88965277   0.122220869  0.80998395  0.8863431
# PT08.S5.O3.    0.075446472 0.89361478   0.124728714  0.63540189  0.9190713
# Temperature   -0.042774479 0.71406041  -0.034310598  0.96595979  0.6303522
# ...

# %%
train
# Out:
#      Date       Time     CO.GT. PT08.S1.CO. NMHC.GT. C6H6.GT. PT08.S2.NMHC.
# 1    2004-10-03 18:00:00    2.6 1360        150      11.9     1046
# 2    2004-10-03 19:00:00    2.0 1292        112       9.4      955
# 3    2004-10-03 20:00:00    2.2 1402         88       9.0      939
# 4    2004-10-03 21:00:00    2.2 1376         80       9.2      948
# 5    2004-10-03 22:00:00    1.6 1272         51       6.5      836
# 6    2004-10-03 23:00:00    1.2 1197         38       4.7      750
# 7    2004-11-03 00:00:00    1.2 1185         31       3.6      690
# 8    2004-11-03 01:00:00    1.0 1136         31       3.3      672
# 9    2004-11-03 02:00:00    0.9 1094         24       2.3      609
# 10   2004-11-03 03:00:00    0.6 1010         19       1.7      561
# 11   2004-11-03 04:00:00 -200.0 1011         14       1.3      527
# 12   2004-11-03 05:00:00    0.7 1066          8       1.1      512
# 13   2004-11-03 06:00:00    0.7 1052         16       1.6      553
# ...
